# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

files = ['coretech.txt.zip', 'background.txt.zip', 'whycolab.txt.zip', 'backgroundAccept.txt.zip']

filename = files[3]

# %%
f = open('test.txt')
f.read()
# vocabulary = tf.compat.as_str(f).split()
print(f)
# print('Data size', len(f))
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='UTF-8'>

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 88026

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 5000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  print(len(reversed_dictionary))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# 5000
# Most common words (+UNK) [['UNK', 6664], ('the', 3689), ('and', 3281), ('to', 3123), ('of', 2476)]
# Sample data [0, 0, 730, 7, 123, 3, 301, 1259, 6, 1937] ['UNK', 'UNK', '--', 'I', 'want', 'to', 'build', 'schools', 'in', 'factories']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 0 UNK -> 0 UNK
# 0 UNK -> 730 --
# 730 -- -> 0 UNK
# 730 -- -> 7 I
# 7 I -> 123 want
# 7 I -> 730 --
# 123 want -> 3 to
# 123 want -> 7 I

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 50001 # was 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  220.130004883
# Nearest to The: crystals, close, School,, recently, story,, reporting, lots, applications,,
# Nearest to not: press, columns, obstacle, educators, police, breathe, basis., discovered,
# Nearest to internet: capabilities, concept,, intelligent, main, house, medicine,, Technology, thought.,
# Nearest to when: events,, K-12, potential,, that, Technologies, adaptation, you're, before,,
# Nearest to they: previously, people., interests, describe, films, above,, conferences,, Having,
# Nearest to future: intelligence., buildings, phase., present, benefits, unmanned, statistical, billion,
# Nearest to we: Doing, exist., big, giants, passengers, offer., dramatically, viewed,
# Nearest to a: globe, communities., today, media, think,, already, running, natural,
# Nearest to into: sickness, foresight, store, preventative, grown, civilian, include, relationships.,
# Nearest to design: consumption., old., lead, --, empathy,, everyday., globe, sense,
# Nearest to technologies: parallel, automate, existing, delivering, collective, this,, Amazon’s, Certainly,,
# Nearest to potential: dramatically, correct, Personally, parking, empathetic, expanded, available, network.,
# Nearest to I: present, Both, movements, countries., suited, What, distributed, “big,
# Nearest to intelligence: tremendous, way., cancer, teenager, firms, and, impact., big,
# Nearest to because: food:, of, furniture, exhibition., us, conscious, Innovation, engagement,
# Nearest to such: overcome, unemployment?, finite, Street, resources,, fuse, targeting, communicating,
# Average loss at step  2000 :  23.2654077377
# Average loss at step  4000 :  4.81559131432
# Average loss at step  6000 :  4.44493965995
# Average loss at step  8000 :  4.27917379761
# Average loss at step  10000 :  4.18706394482
# Nearest to The: close, With, recently, shift., isolated, crystals, the, gesture,,
# Nearest to not: press, seeks, seen, police, basis., conferences,, columns, obstacle,
# Nearest to internet: capabilities, medicine,, concept,, next, main, space., Technology, house,
# Nearest to when: K-12, Technologies, that, every, payday, world's, adaptation, events,,
# Nearest to they: we, previously, interests, films, medias, people., variable, hoped,
# Nearest to future: present, buildings, intelligence., benefits, phase., billion, statistical, disciplines,,
# Nearest to we: they, big, drawing, Doing, I, explorations, giants, controllers,
# Nearest to a: already, globe, prototype, activity, increasingly, appliances, complexities, programmed,
# Nearest to into: sickness, store, foresight, launched, civilian, include, both, grown,
# Nearest to design: consumption., old., lead, --, door, everyday., empathy,, month.,
# Nearest to technologies: this,, delivering, versus, view, parallel, Things., automate, collective,
# Nearest to potential: street, Alexa, parking, woman-identified, four, correct, network., available,
# Nearest to I: we, previously, We, markets,, thrive., "I, exposed, learners,
# Nearest to intelligence: tremendous, firms, goods, teenager, impact., big, cancer, programs,
# Nearest to because: food:, input, engagement, computerized, furniture, architectural, exhibition., will,
# Nearest to such: fabric, overcome, communicating, Street, tinkering, formal, participate, corrupt,
# Average loss at step  12000 :  4.07627600515
# Average loss at step  14000 :  4.02710144758
# Average loss at step  16000 :  3.94473149669
# Average loss at step  18000 :  3.90174313593
# Average loss at step  20000 :  3.84264233267
# Nearest to The: With, close, shift., isolated, crystals, gesture,, recently, growth.,
# Nearest to not: press, seen, seeks, directed, conferences,, what’s, columns, basis.,
# Nearest to internet: next, concept,, capabilities, medicine,, public, context, main, space.,
# Nearest to when: payday, K-12, tasks, every, Technologies, manage, world's, adaptation,
# Nearest to they: we, previously, hoped, films, medias, variable, Having, I,
# Nearest to future: present, buildings, intelligence., benefits, phase., statistical, coding, bottom,
# Nearest to we: they, big, I, drawing, Doing, controllers, people, giants,
# Nearest to a: programmed, already, activity, prototype, disrupted, appliances, increasingly, mediums,
# Nearest to into: sickness, store, civilian, launched, State, elevate, healthy, true,
# Nearest to design: consumption., door, old., everyday., lead, --, empathy,, month.,
# Nearest to technologies: view, Things., this,, parallel, delivering, tool,, versus, AI),
# Nearest to potential: street, woman-identified, pursuit, Bank, managed, Alexa, socio-economic, network.,
# Nearest to I: we, We, "I, previously, thrive., markets,, I’m, frequently,
# Nearest to intelligence: tremendous, firms, goods, AR, programs, teenager, telling, everybody.,
# Nearest to because: food:, input, architectural, dollars, furniture, computerized, “big, excites,
# Nearest to such: fabric, tinkering, formal, Street, communicating, overcome, participate, corrupt,
# Average loss at step  22000 :  3.8051002177
# Average loss at step  24000 :  3.77524239469
# Average loss at step  26000 :  3.71837800539
# Average loss at step  28000 :  3.7123216337
# Average loss at step  30000 :  3.65234640169
# Nearest to The: With, close, crystals, growth., based, Black, shift., My,
# Nearest to not: press, seen, seeks, directed, conferences,, what’s, simple,, Reality.,
# Nearest to internet: context, next, public, concept,, medicine,, capabilities, resulting, main,
# Nearest to when: payday, K-12, tasks, manage, every, rather, maintenance, Steve,
# Nearest to they: we, previously, hoped, medias, I, films, Having, variable,
# Nearest to future: buildings, present, benefits, bottom, coding, intelligence., statistical, phase.,
# Nearest to we: they, I, drawing, big, Doing, controllers, giants, people,
# Nearest to a: programmed, appliances, mediums, already, activity, disrupted, Environmental, prototype,
# Nearest to into: sickness, civilian, launched, State, store, elevate, healthy, logistics,,
# Nearest to design: everyday., consumption., door, old., lead, automated, empathy,, view,
# Nearest to technologies: Things., view, this,, parallel, tool,, AI), interfaces, delivering,
# Nearest to potential: pursuit, Bank, woman-identified, street, planet, managed, potentials, socio-economic,
# Nearest to I: "I, we, We, thrive., they, productivity., I’m, frequently,
# Nearest to intelligence: tremendous, firms, goods, telling, AR, everybody., teenager, before,,
# Nearest to because: food:, dollars, input, “big, architectural, furniture, object, excites,
# Nearest to such: fabric, formal, tinkering, participate, order, corrupt, Street, vast,
# Average loss at step  32000 :  3.65539850831
# Average loss at step  34000 :  3.60197725475
# Average loss at step  36000 :  3.60461702597
# Average loss at step  38000 :  3.56281302738
# Average loss at step  40000 :  3.55226049662
# Nearest to The: With, growth., based, Black, crystals, My, CoLab,, close,
# Nearest to not: seen, press, directed, seeks, conferences,, Reality., elaborate, always,
# Nearest to internet: public, context, next, concept,, medicine,, resulting, capabilities, Technology,
# Nearest to when: payday, manage, feedback,, Steve, K-12, rather, tasks, maintenance,
# Nearest to they: we, previously, hoped, I, films, medias, computers, Having,
# Nearest to future: buildings, bottom, coding, present, benefits, statistical, vision,, intersection,
# Nearest to we: they, drawing, I, big, Doing, controllers, giants, else,
# Nearest to a: programmed, Environmental, appliances, mediums, disrupted, tactile, hundreds, activity,
# Nearest to into: sickness, civilian, launched, elevate, State, well, store, majority,
# Nearest to design: everyday., consumption., old., door, view, automated, Disneyland, air,
# Nearest to technologies: Things., view, tool,, parallel, this,, AI), interfaces, insights,
# Nearest to potential: pursuit, potentials, Bank, planet, socio-economic, customize, applicability, mechanical,
# Nearest to I: "I, We, we, they, productivity., I've, frequently, thrive.,
# Nearest to intelligence: goods, telling, firms, tremendous, Intelligence, before,, AR, everybody.,
# Nearest to because: dollars, “big, food:, input, architectural, furniture, object, limiting,
# Nearest to such: fabric, participate, formal, tinkering, vast, order, points, corrupt,
# Average loss at step  42000 :  3.52901571107
# Average loss at step  44000 :  3.5112312187
# Average loss at step  46000 :  3.5091970588
# Average loss at step  48000 :  3.46862949502
# Average loss at step  50000 :  3.47749455309
# Nearest to The: With, growth., Black, based, crystals, CoLab,, My, startup.,
# Nearest to not: seen, press, directed, seeks, elaborate, Reality., conferences,, always,
# Nearest to internet: public, context, concept,, next, IoT., resulting, this,, medicine,,
# Nearest to when: payday, manage, rather, feedback,, Steve, equipment,, K-12, maintenance,
# Nearest to they: we, I, hoped, previously, computers, films, medias, variable,
# Nearest to future: buildings, bottom, coding, experienced, intersection, statistical, experts, source,
# Nearest to we: they, drawing, I, controllers, big, giants, else, Doing,
# Nearest to a: programmed, Environmental, appliances, mediums, tactile, disrupted, bitcoin, hundreds,
# Nearest to into: sickness, civilian, well, elevate, launched, store, majority, evolutionary,
# Nearest to design: everyday., view, old., door, Disneyland, air, consumption., automated,
# Nearest to technologies: Things., interfaces, view, tool,, insights, parallel, this,, AI),
# Nearest to potential: potentials, pursuit, Bank, customize, applicability, planet, end, socio-economic,
# Nearest to I: "I, We, we, they, I've, productivity., thrive., I’m,
# Nearest to intelligence: telling, goods, firms, before,, tremendous, Intelligence, algorithms, everybody.,
# Nearest to because: dollars, “big, limiting, tied, input, furniture, offer., object,
# Nearest to such: fabric, participate, order, vast, formal, tinkering, points, definitely,

# %%
# # Step 6: Visualize the embeddings.


def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  # import matplotlib
  # matplotlib.use('TkAgg')
  import matplotlib.pyplot as plt
  # %matplotlib inline

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 250
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
